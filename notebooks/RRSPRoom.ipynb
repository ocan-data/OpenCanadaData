# %% [markdown]
# ## RRSP Room

# %%
import numpy as np
import pandas as pd
import requests, zipfile, io
import re
import os

# %%
# %load_ext autoreload
# %autoreload 2
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 400)

data_dir = '../data'
cache_dir = os.path.join(data_dir, 'cache')
import sys
sys.path.append('..')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from canadadata.statscan import to_wide_format, read_statscan_csv, StatscanDataset
from canadadata.io import unzip_data

rrsp_dataset = StatscanDataset('https://www150.statcan.gc.ca/n1/tbl/csv/11100045-eng.zip', 
                                        pivot_column='Registered Retirement Savings Plan (RRSP) room')
rrsp_room = rrsp_dataset.get_wide_data(cache_dir=cache_dir, index_col='REF_DATE')

# %%
rrsp_room
# Out:
#                                                   GEO  \
# REF_DATE
# 2000                                           Canada
# 2000                        Newfoundland and Labrador
# 2000            St. John's, Newfoundland and Labrador
# 2000                             Prince Edward Island
# 2000                                      Nova Scotia
# 2000                             Halifax, Nova Scotia
# 2000                                    New Brunswick
# 2000                        Saint John, New Brunswick
# 2000                                           Quebec
# 2000                                 Saguenay, Quebec
# 2000                                   Québec, Quebec
# 2000                               Sherbrooke, Quebec
# 2000                           Trois-Rivières, Quebec
# 2000                                 Montréal, Quebec
# 2000                     Ottawa-Gatineau, Quebec part
# 2000                                          Ontario
# ...

# %%
rrsp_room_2016 = rrsp_room[rrsp_room.index ==2016]

# %%
rrsp_room_2016[rrsp_room_2016.GEO.str.match('.*Ontario')]
# Out:
#                                                  GEO  \
# REF_DATE
# 2016                                         Ontario
# 2016                               Cornwall, Ontario
# 2016                        Hawkesbury, Ontario part
# 2016                   Ottawa-Gatineau, Ontario part
# 2016                               Arnprior, Ontario
# 2016                         Carleton Place, Ontario
# 2016                             Brockville, Ontario
# 2016                               Pembroke, Ontario
# 2016                               Petawawa, Ontario
# 2016                               Kingston, Ontario
# 2016                             Belleville, Ontario
# 2016                                Cobourg, Ontario
# 2016                              Port Hope, Ontario
# 2016                           Peterborough, Ontario
# 2016                         Kawartha Lakes, Ontario
# 2016                      Centre Wellington, Ontario
# ...
