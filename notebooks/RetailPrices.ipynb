# %% [markdown]
# # Retail Prices

# %% [markdown]
# ## Technical Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %run relativepath.py
# %run commonimports.py
# %run displayoptions.py

# %% [markdown]
# ## Retail Prices

# %%
retail_prices_dataset = StatscanZip('https://www150.statcan.gc.ca/n1/tbl/csv/18100251-eng.zip')
retail_prices = retail_prices_dataset.get_data()
retail_prices

# %%
retail_prices.T

# %% [markdown]
# ## Units of Measure

# %%
cpi_dataset = StatscanZip('https://www150.statcan.gc.ca/n1/tbl/csv/18100004-eng.zip')
cpi_data = cpi_dataset.get_data(drop_control_cols=False, wide=False)

# %%
cpi_data
# Out:
#        REF_DATE                                 GEO             DGUID  \
# 0       1914-01                              Canada    2016A000011124
# 1       1914-01                              Canada    2016A000011124
# 2       1914-01                              Canada    2016A000011124
# 3       1914-02                              Canada    2016A000011124
# 4       1914-02                              Canada    2016A000011124
# 5       1914-02                              Canada    2016A000011124
# 6       1914-03                              Canada    2016A000011124
# 7       1914-03                              Canada    2016A000011124
# 8       1914-03                              Canada    2016A000011124
# 9       1914-04                              Canada    2016A000011124
# 10      1914-04                              Canada    2016A000011124
# 11      1914-04                              Canada    2016A000011124
# ...

# %%
cpi_dataset.primary_dimension()
# Out:
# 'Products and product groups'

# %%
cpi_data[[cpi_dataset.primary_dimension(), 'UOM']].drop_duplicates().set_index(cpi_dataset.primary_dimension())
# Out:
#                                                                                                                   UOM
# Products and product groups
# All-items                                                                                                    2002=100
# All-items (1992=100)                                                                                         1992=100
# Goods and services                                                                                           2002=100
# Food                                                                                                         2002=100
# Fresh or frozen poultry                                                                                      2002=100
# Fresh or frozen chicken                                                                                      2002=100
# Dairy products                                                                                               2002=100
# ...

# %%
cpi_dataset.get_units_of_measure()
# Out:
#                                                                                                                   UOM
# Products and product groups
# Air transportation                                                                                           2002=100
# Alcoholic beverages                                                                                          2002=100
# Alcoholic beverages purchased from stores                                                                    2002=100
# Alcoholic beverages served in licensed establishments                                                        2002=100
# Alcoholic beverages, tobacco products and recreational cannabis                                              2002=100
# All other food preparations                                                                                  2002=100
# All other miscellaneous food preparations (2013=100)                                                         2013=100
# ...
