# %% [markdown]
# # StatscanDataset

# %%
# %load_ext autoreload
# %autoreload 2

# %run relativepath.py
# %run commonimports.py
# %run displayoptions.py

# %% [markdown]
# ## Statscan Zip

# %%
prices_zip = StatscanZip('https://www150.statcan.gc.ca/n1/tbl/csv/18100251-eng.zip', local_path='../data/cache')

# %% [markdown]
# ### Metadata

# %%
prices_metadata = prices_zip.get_metadata()
prices_metadata.dimensions
# Out:
#                                                      Dimension name  \
# Dimension ID
# 1                                                         Geography
# 2             North American Industry Classification System (NAICS)
#
#              Dimension Notes Dimension Definitions
# Dimension ID
# 1                        NaN                   NaN
# 2                        NaN                   NaN

# %%
prices_metadata.pivot_column()
# Out:
# 'North American Industry Classification System (NAICS)'

# %%
prices_zip.get_data()
# Out:
#     REF_DATE     GEO  All other general merchandise stores  \
# 0    2008-01  Canada                                  97.9
# 1    2008-02  Canada                                  97.1
# 2    2008-03  Canada                                  95.6
# 3    2008-04  Canada                                  95.3
# 4    2008-05  Canada                                  97.4
# 5    2008-06  Canada                                 103.0
# 6    2008-07  Canada                                  98.0
# 7    2008-08  Canada                                  98.1
# 8    2008-09  Canada                                  97.6
# 9    2008-10  Canada                                  93.0
# 10   2008-11  Canada                                  92.2
# 11   2008-12  Canada                                  93.2
# 12   2009-01  Canada                                  88.8
# 13   2009-02  Canada                                  94.3
# 14   2009-03  Canada                                  88.0
# ...

# %%
prices_zip.get_data(drop_control_cols=False)
# Out:
#     REF_DATE     GEO           DGUID              UOM UOM_ID SCALAR_FACTOR  \
# 0    2008-01  Canada  2016A000011124  Index, 2013=100    186        units
# 1    2008-02  Canada  2016A000011124  Index, 2013=100    186        units
# 2    2008-03  Canada  2016A000011124  Index, 2013=100    186        units
# 3    2008-04  Canada  2016A000011124  Index, 2013=100    186        units
# 4    2008-05  Canada  2016A000011124  Index, 2013=100    186        units
# 5    2008-06  Canada  2016A000011124  Index, 2013=100    186        units
# 6    2008-07  Canada  2016A000011124  Index, 2013=100    186        units
# 7    2008-08  Canada  2016A000011124  Index, 2013=100    186        units
# 8    2008-09  Canada  2016A000011124  Index, 2013=100    186        units
# 9    2008-10  Canada  2016A000011124  Index, 2013=100    186        units
# 10   2008-11  Canada  2016A000011124  Index, 2013=100    186        units
# 11   2008-12  Canada  2016A000011124  Index, 2013=100    186        units
# ...

# %% [markdown]
# # Number of job vacancies and average offered hourly wage by one-digit National Occupational Classification (NOC) code, last 5 quarters.

# %%
StatscanZip('https://www150.statcan.gc.ca/n1/tbl/csv/14100356-eng.zip', local_path='../data/cache').get_data()
# Out:
#        REF_DATE                    GEO  \
# 0       2015-01                 Canada
# 1       2015-01                 Canada
# 2       2015-01                 Canada
# 3       2015-01                 Canada
# 4       2015-01                 Canada
# 5       2015-01                 Canada
# 6       2015-01                 Canada
# 7       2015-01                 Canada
# 8       2015-01                 Canada
# 9       2015-01                 Canada
# 10      2015-01                 Canada
# 11      2015-01                 Canada
# 12      2015-01                 Canada
# 13      2015-01                 Canada
# 14      2015-01                 Canada
# 15      2015-01                 Canada
# 16      2015-01                 Canada
# 17      2015-01                 Canada
# 18      2015-01                 Canada
# 19      2015-01                 Canada
# 20      2015-01                 Canada
# 21      2015-01                 Canada
# 22      2015-01                 Canada
# ...

# %% [markdown]
# ## Life Expectancy

# %%
life_expectancy = StatscanZip('https://www150.statcan.gc.ca/n1/tbl/csv/13100114-eng.zip', local_path='../data/cache').get_data(drop_control_cols=False, wide=False)

# %%
life_expectancy
# Out:
#           REF_DATE               GEO           DGUID           Age group  \
# 0        1980/1982            Canada  2016A000011124             0 years
# 1        1980/1982            Canada  2016A000011124             0 years
# 2        1980/1982            Canada  2016A000011124             0 years
# 3        1980/1982            Canada  2016A000011124             0 years
# 4        1980/1982            Canada  2016A000011124             0 years
# 5        1980/1982            Canada  2016A000011124             0 years
# 6        1980/1982            Canada  2016A000011124             0 years
# 7        1980/1982            Canada  2016A000011124             0 years
# 8        1980/1982            Canada  2016A000011124             0 years
# 9        1980/1982            Canada  2016A000011124             0 years
# 10       1980/1982            Canada  2016A000011124             0 years
# 11       1980/1982            Canada  2016A000011124             0 years
# ...
