# %% [markdown]
# ## Metadata

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 500)

# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %% [markdown]
# ## Read Metadata

# %%
from opencanada.statscan import StatscanMetadata
import glob

metadata_dfs = [pd.read_csv(f) for f in list(glob.glob('../data/cache/*MetaData.csv'))]
metadatas = [StatscanMetadata(df) for df in metadata_dfs]

# %% [markdown]
# ## Metadata

# %%
metadatas[0]
# Out:
# <Financial Data and Charitable Donations, Preliminary T1 Family File>

# %%
metadatas[1]
# Out:
# <Financial Data and Charitable Donations, Preliminary T1 Family File>

# %%
metadatas[2]
# Out:
# <Vital Statistics - Death Database>
