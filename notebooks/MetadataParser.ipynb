# %% [markdown]
# ## Metadata

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 500)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('..')

# %%
from canadadata.statscan import DatasetMetadata
import glob

metadata_files = [pd.read_csv(f) for f in list(glob.glob('../data/cache/*MetaData.csv'))]

# %%
metadata0 = DatasetMetadata(metadata_files[5])

# %%
metadata0.cube_info
# Out:
#                                                                            Product Id  \
# Cube Title
# Life expectancy and other elements of the life table, Canada and provinces   39100007
#
#                                                                            CANSIM Id  \
# Cube Title
# Life expectancy and other elements of the life table, Canada and provinces  053-0003
#
#                                                                                                                                          URL  \
# Cube Title
# Life expectancy and other elements of the life table, Canada and provinces  https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3910000701
#
#                                                                            Cube Notes  \
# Cube Title
# Life expectancy and other elements of the life table, Canada and provinces      12;13
#
# ...

# %%
metadata0.survey
# Out:
#                                    Survey Name
# Survey Code
# 3233         Vital Statistics - Death Database

# %%
metadata0.dimensions
# Out:
#              Dimension name  \
# Dimension ID
# 1                 Geography
# 2                 Age group
# 3                       Sex
# 4                   Element
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Dimension Notes  \
# Dimension ID
# ...

# %%
metadata0.dimension_details
# Out:
#                                                                    Member Name  \
# Dimension ID
# 1                                                                       Canada
# 1                                                    Newfoundland and Labrador
# 1                                                         Prince Edward Island
# 1                                                                  Nova Scotia
# 1                                                                New Brunswick
# 1                                                                       Quebec
# 1                                                                      Ontario
# 1                                                                     Manitoba
# 1                                                                 Saskatchewan
# 1                                                                      Alberta
# 1                                                             British Columbia
# ...

# %%
metadata0.note
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Note
# Note ID
# ...
