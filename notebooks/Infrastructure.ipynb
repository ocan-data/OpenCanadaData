# %%
import pandas as pd

pd.set_option('display.max_colwidth', 500)
pd.options.display.float_format = '${:,.2f}'.format

# %%
pd.read_csv('../data/project-list-en.csv', encoding='latin-1')
# Out:
#       projectNumber  \
# 0             52616
# 1             51915
# 2             52427
# 3             52379
# 4             51703
# 5           51885-1
# 6           51885-2
# 7             51981
# 8             51906
# 9             47352
# 10            47492
# 11            51327
# 12            51867
# 13            51982
# 14            51983
# 15            51984
# 16            51985
# 17            51986
# 18            51987
# 19            51988
# 20            51989
# 21            51990
# 22            51991
# 23            51992
# 24            51993
# 25            51994
# 26            51995
# 27            51997
# 28            51998
# 29            51999
# ...             ...
# 13679         52407
# 13680         51892
# 13681         51890
# 13682         51931
# 13683         51889
# 13684         52161
# 13685         52160
# 13686         52162
# 13687         52163
# 13688         52166
# 13689         52165
# 13690         52164
# 13691         52159
# ...
