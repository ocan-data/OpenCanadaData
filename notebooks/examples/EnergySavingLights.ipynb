# %% [markdown]
# # Energy Saving Lights

# %%
import sys

sys.path.append('../..')

# %%
import pandas as pd

from ocandata import StatscanZip

# %%
zip: StatscanZip = StatscanZip('https://www150.statcan.gc.ca/n1/tbl/csv/38100048-eng.zip')
data = zip.get_data()
# Out:
# Extracting files to C:\Users\dwight\.repo\repo\extracted\8614951a1df4f087106afa4a0e46bc9216162aff

# %%
data
# Out:
#      REF_DATE                                    GEO  \
# 0        2007                                 Canada
# 1        2007              Newfoundland and Labrador
# 2        2007                   Prince Edward Island
# 3        2007                            Nova Scotia
# 4        2007                          New Brunswick
# 5        2007                                 Quebec
# 6        2007                                Ontario
# 7        2007                               Manitoba
# 8        2007                           Saskatchewan
# 9        2007                                Alberta
# 10       2007                       British Columbia
# 11       2009                                 Canada
# 12       2009              Newfoundland and Labrador
# 13       2009                   Prince Edward Island
# 14       2009                            Nova Scotia
# 15       2009                          New Brunswick
# 16       2009                                 Quebec
# ...

# %%
data.GEO.drop_duplicates()
# Out:
# 0                                    Canada
# 1                 Newfoundland and Labrador
# 2                      Prince Edward Island
# 3                               Nova Scotia
# 4                             New Brunswick
# 5                                    Quebec
# 6                                   Ontario
# 7                                  Manitoba
# 8                              Saskatchewan
# 9                                   Alberta
# 10                         British Columbia
# 44          Total census metropolitan areas
# 45    St. John's, Newfoundland and Labrador
# 46                     Halifax, Nova Scotia
# 47                   Moncton, New Brunswick
# 48                Saint John, New Brunswick
# 49                         Saguenay, Quebec
# 50                           Québec, Quebec
# 51                       Sherbrooke, Quebec
# 52                   Trois-Rivières, Quebec
# 53                         Montréal, Quebec
# ...
