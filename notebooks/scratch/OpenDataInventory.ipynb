# %% [markdown]
# # Open Data Inventory

# %%
import pandas as pd
import sys
sys.path.append('../..')

# %load_ext autoreload
# %autoreload 2

# %run ../commonimports.py

# %%
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# ## Inventory

# %%
inventory = pd.read_csv('../../data/inventory.csv')

# %%
statscan_inventory = inventory.query("publisher_en == 'Statistics Canada'")

# %%
statscan_inventory[statscan_inventory.description_en.str.match('.*Rail.*')].set_index('ref_number')
# Out:
#                                                                                                                            title_en  \
# ref_number
# OD-2016-01626     Railway transport survey, property accounts summary of assets and accumulated amortization, by mainline companies
# OD-2016-02500                              Railway transport survey, inventory of equipment in service summary of regional railways
# OD-2016-02757                                                        Railway transport survey, balance sheet, by mainline companies
# OD-2016-02986                                                            Rail transportation, origin and destination of commodities
# OD-2016-03296                                                                     Railway transport survey, diesel fuel consumption
# OD-2016-06176     Rail transportation, length of track operated for freight and passenger transportation, by province and territory
# ...
